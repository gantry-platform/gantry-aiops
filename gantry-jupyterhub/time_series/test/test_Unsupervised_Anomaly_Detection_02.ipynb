# %% [markdown]
# Algorithm implemented :
# Cluster based anomaly detection (K-mean)
# Repartition of data into categories then Gaussian/Elliptic Enveloppe on each categories separately
# Markov Chain
# Isolation Forest
# One class SVM
# RNN (comparison between prediction and reality)
# https://www.kaggle.com/victorambonati/unsupervised-anomaly-detection

# %%
#%matplotlib notebook

import pandas as pd
import numpy as np

import matplotlib
import seaborn
import matplotlib.dates as md
from matplotlib import pyplot as plt

from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.covariance import EllipticEnvelope
#from pyemma import msm # not available on Kaggle Kernel
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM

# %%
def getDistanceByPoint(data, model):
    distance = pd.Series()
    for i in range(0,len(data)):
        Xa = np.array(data.loc[i])
        Xb = model.cluster_centers_[model.labels_[i]-1]
        #distance.set_value(i, np.linalg.norm(Xa-Xb))
        distance.at[i] = np.linalg.norm(Xa-Xb)
    return distance

# train markov model to get transition matrix
def getTransitionMatrix (df):
    df = np.array(df)
    model = msm.estimate_markov_model(df, 1)
    return model.transition_matrix

def markovAnomaly(df, windows_size, threshold):
    transition_matrix = getTransitionMatrix(df)
    real_threshold = threshold**windows_size
    df_anomaly = []
    for j in range(0, len(df)):
        if (j < windows_size):
            df_anomaly.append(0)
        else:
            sequence = df[j-windows_size:j]
            sequence = sequence.reset_index(drop=True)
            df_anomaly.append(anomalyElement(sequence, real_threshold, transition_matrix))
    return df_anomaly

# %%
df = pd.read_csv('./m_data_fromNow_test01.csv', usecols=['date', 'time', 'cpu'])
df.head()
# Out:
#          date      time       cpu
# 0  2020-07-04  00:10:00  2.398816
# 1  2020-07-04  00:20:00  2.370533
# 2  2020-07-04  00:30:00  2.670351
# 3  2020-07-04  00:40:00  2.578600
# 4  2020-07-04  00:50:00  2.583533

# %%
df['timestamp'] = df[df.columns[0:2]]. apply(
    lambda x: ' '.join(x.dropna().astype(str)),
    axis=1)
df.head()
# Out:
#          date      time       cpu            timestamp
# 0  2020-07-04  00:10:00  2.398816  2020-07-04 00:10:00
# 1  2020-07-04  00:20:00  2.370533  2020-07-04 00:20:00
# 2  2020-07-04  00:30:00  2.670351  2020-07-04 00:30:00
# 3  2020-07-04  00:40:00  2.578600  2020-07-04 00:40:00
# 4  2020-07-04  00:50:00  2.583533  2020-07-04 00:50:00

# %%
df = df[['timestamp', 'cpu']]
df.head()
# Out:
#              timestamp       cpu
# 0  2020-07-04 00:10:00  2.398816
# 1  2020-07-04 00:20:00  2.370533
# 2  2020-07-04 00:30:00  2.670351
# 3  2020-07-04 00:40:00  2.578600
# 4  2020-07-04 00:50:00  2.583533

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2078 entries, 0 to 2077
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  2078 non-null   object
#  1   cpu        2078 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 32.6+ KB
# None

# %%
print(df['timestamp'].head())
# Out:
# 0    2020-07-04 00:10:00
# 1    2020-07-04 00:20:00
# 2    2020-07-04 00:30:00
# 3    2020-07-04 00:40:00
# 4    2020-07-04 00:50:00
# Name: timestamp, dtype: object

# %%
print(df['cpu'].mean())
# Out:
# 2.0535663735960816

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])
df.plot(x = 'timestamp', y='cpu')
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
df['hours'] = df['timestamp'].dt.hour
df['daylight'] = ((df['hours'] >= 8) & (df['hours'] <= 19)).astype(int)
df.head(30)
# Out:
#              timestamp       cpu  hours  daylight
# 0  2020-07-04 00:10:00  2.398816      0         0
# 1  2020-07-04 00:20:00  2.370533      0         0
# 2  2020-07-04 00:30:00  2.670351      0         0
# 3  2020-07-04 00:40:00  2.578600      0         0
# 4  2020-07-04 00:50:00  2.583533      0         0
# 5  2020-07-04 01:00:00  2.638800      1         0
# 6  2020-07-04 01:10:00  2.281600      1         0
# 7  2020-07-04 01:20:00  2.591516      1         0
# 8  2020-07-04 01:30:00  2.308118      1         0
# 9  2020-07-04 01:40:00  2.637456      1         0
# 10 2020-07-04 01:50:00  2.499333      1         0
# 11 2020-07-04 02:00:00  2.587667      2         0
# 12 2020-07-04 02:10:00  2.649400      2         0
# 13 2020-07-04 02:20:00  2.578067      2         0
# 14 2020-07-04 02:30:00  2.152319      2         0
# 15 2020-07-04 02:40:00  2.575133      2         0
# 16 2020-07-04 02:50:00  2.568000      2         0
# 17 2020-07-04 03:00:00  2.574400      3         0
# 18 2020-07-04 03:10:00  2.558533      3         0
# 19 2020-07-04 03:20:00  2.408800      3         0
# 20 2020-07-04 03:30:00  2.458133      3         0
# 21 2020-07-04 03:40:00  2.449733      3         0
# 22 2020-07-04 03:50:00  2.598133      3         0
# 23 2020-07-04 04:00:00  2.584884      4         0
# 24 2020-07-04 04:10:00  2.410933      4         0
# 25 2020-07-04 04:20:00  2.724267      4         0
# 26 2020-07-04 04:30:00  2.656133      4         0
# 27 2020-07-04 04:40:00  2.622667      4         0
# 28 2020-07-04 04:50:00  2.471400      4         0
# 29 2020-07-04 05:00:00  2.471467      5         0

# %%
s = pd.date_range('2020-06-29', '2020-07-10').to_series()
s.dt.dayofweek
# Out:
# 2020-06-29    0
# 2020-06-30    1
# 2020-07-01    2
# 2020-07-02    3
# 2020-07-03    4
# 2020-07-04    5
# 2020-07-05    6
# 2020-07-06    0
# 2020-07-07    1
# 2020-07-08    2
# 2020-07-09    3
# 2020-07-10    4
# Freq: D, dtype: int64

# %%
df['DayOfTheWeek'] = df['timestamp'].dt.dayofweek
df['WeekDay'] = (df['DayOfTheWeek'] < 5).astype(int)
outliers_fraction = 0.01

# %%
df['time_epoch'] = (df['timestamp'].astype(np.int64)/100000000000).astype(np.int64)

# %%
df['categories'] = df['WeekDay']*2 + df['daylight']


a = df.loc[df['categories'] == 0, 'cpu']
b = df.loc[df['categories'] == 1, 'cpu']
c = df.loc[df['categories'] == 2, 'cpu']
d = df.loc[df['categories'] == 3, 'cpu']

# %%
fig, ax = plt.subplots()
a_heights, a_bins = np.histogram(a)
b_heights, b_bins = np.histogram(b, bins=a_bins)
c_heights, c_bins = np.histogram(c, bins=a_bins)
d_heights, d_bins = np.histogram(d, bins=a_bins)

width = (a_bins[1] - a_bins[0])/6

ax.bar(a_bins[:-1], a_heights*100/a.count(), width=width, facecolor='blue', label='WeekEndNight')
ax.bar(b_bins[:-1]+width, (b_heights*100/b.count()), width=width, facecolor='green', label ='WeekEndLight')
ax.bar(c_bins[:-1]+width*2, (c_heights*100/c.count()), width=width, facecolor='red', label ='WeekDayNight')
ax.bar(d_bins[:-1]+width*3, (d_heights*100/d.count()), width=width, facecolor='black', label ='WeekDayLight')

plt.rcParams['figure.figsize'] = [10, 5]
plt.legend()

# %%
# Take useful feature and standardize them
data = df[['cpu', 'hours', 'daylight', 'DayOfTheWeek', 'WeekDay']]
min_max_scaler = preprocessing.StandardScaler()
np_scaled = min_max_scaler.fit_transform(data)
data = pd.DataFrame(np_scaled)
# reduce to 2 importants features
pca = PCA(n_components=2)
data = pca.fit_transform(data)
# standardize these 2 new features
min_max_scaler = preprocessing.StandardScaler()
np_scaled = min_max_scaler.fit_transform(data)
data = pd.DataFrame(np_scaled)

# %%
# calculate with different number of centroids to see the loss plot (elbow method)
n_cluster = range(1, 20)
kmeans = [KMeans(n_clusters=i).fit(data) for i in n_cluster]
scores = [kmeans[i].score(data) for i in range(len(kmeans))]
fig, ax = plt.subplots()
ax.plot(n_cluster, scores)

# %%
# Not clear for me, I choose 15 centroids arbitrarily and add these data to the central dataframe
df['cluster'] = kmeans[14].predict(data)
df['principal_feature1'] = data[0]
df['principal_feature2'] = data[1]
df['cluster'].value_counts()
# Out:
# 6     192
# 14    190
# 8     183
# 1     162
# 11    141
# 12    132
# 10    130
# 7     129
# 9     127
# 3     127
# 4     126
# 13    125
# 5     125
# 0      96
# 2      93
# Name: cluster, dtype: int64

# %%
#plot the different clusters with the 2 main features
fig, ax = plt.subplots()
colors = {0:'red', 1:'blue', 2:'green', 3:'pink', 4:'black', 5:'orange', 6:'cyan', 7:'yellow', 8:'brown', 9:'purple', 10:'white', 11: 'grey', 12:'lightblue', 13:'lightgreen', 14: 'darkgrey'}
ax.scatter(df['principal_feature1'], df['principal_feature2'], c=df["cluster"].apply(lambda x: colors[x]))
plt.show()

# %%
# get the distance between each point and its nearest centroid. The biggest distances are considered as anomaly
distance = getDistanceByPoint(data, kmeans[14])
number_of_outliers = int(outliers_fraction*len(distance))
threshold = distance.nlargest(number_of_outliers).min()
# anomaly21 contain the anomaly result of method 2.1 Cluster (0:normal, 1:anomaly) 
df['anomaly21'] = (distance >= threshold).astype(int)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.

# %%
fig, ax = plt.subplots()
color = {0:'blue', 1:'red'}
ax.scatter(df['principal_feature1'], df['principal_feature2'], c=df["anomaly21"].apply(lambda x: color[x]))
plt.show()

# %%
fig, ax = plt.subplots()
a = df.loc[df['anomaly21'] == 1, ['time_epoch', 'cpu']] #anomaly

ax.plot(df['time_epoch'], df['cpu'], color = 'blue')
ax.scatter(a['time_epoch'], a['cpu'], color = 'red')
plt.show()

# %%
a = df.loc[df['anomaly21'] == 0, 'cpu']
b = df.loc[df['anomaly21'] == 1, 'cpu']

fig, axs = plt.subplots()
axs.hist([a, b], bins=32, stacked=True, color=['blue', 'red'], label = ['normal', 'anomaly'])
plt.legend()
plt.show()

# %% [markdown]
# ## Categories + Gaussian

# %%
# creation of 4 differents data set based on categories defined before
df_class0 = df.loc[df['categories'] == 0, 'cpu']
df_class1 = df.loc[df['categories'] == 1, 'cpu']
df_class2 = df.loc[df['categories'] == 2, 'cpu']
df_class3 = df.loc[df['categories'] == 3, 'cpu']

# %%
# plot the temperature repartition by categories
fig, axs = plt.subplots(2,2)
df_class0.hist(ax=axs[0,0],bins=32)
df_class1.hist(ax=axs[0,1],bins=32)
df_class2.hist(ax=axs[1,0],bins=32)
df_class3.hist(ax=axs[1,1],bins=32)
# Out:
# <AxesSubplot:>

# %%
envelope =  EllipticEnvelope(contamination = outliers_fraction) 
X_train = df_class0.values.reshape(-1,1)
envelope.fit(X_train)
df_class0 = pd.DataFrame(df_class0)
df_class0['deviation'] = envelope.decision_function(X_train)
df_class0['anomaly'] = envelope.predict(X_train)

envelope =  EllipticEnvelope(contamination = outliers_fraction) 
X_train = df_class1.values.reshape(-1,1)
envelope.fit(X_train)
df_class1 = pd.DataFrame(df_class1)
df_class1['deviation'] = envelope.decision_function(X_train)
df_class1['anomaly'] = envelope.predict(X_train)

envelope =  EllipticEnvelope(contamination = outliers_fraction) 
X_train = df_class2.values.reshape(-1,1)
envelope.fit(X_train)
df_class2 = pd.DataFrame(df_class2)
df_class2['deviation'] = envelope.decision_function(X_train)
df_class2['anomaly'] = envelope.predict(X_train)

envelope =  EllipticEnvelope(contamination = outliers_fraction) 
X_train = df_class3.values.reshape(-1,1)
envelope.fit(X_train)
df_class3 = pd.DataFrame(df_class3)
df_class3['deviation'] = envelope.decision_function(X_train)
df_class3['anomaly'] = envelope.predict(X_train)

# %%
# plot the temperature repartition by categories with anomalies
a0 = df_class0.loc[df_class0['anomaly'] == 1, 'cpu']
b0 = df_class0.loc[df_class0['anomaly'] == -1, 'cpu']

a1 = df_class1.loc[df_class1['anomaly'] == 1, 'cpu']
b1 = df_class1.loc[df_class1['anomaly'] == -1, 'cpu']

a2 = df_class2.loc[df_class2['anomaly'] == 1, 'cpu']
b2 = df_class2.loc[df_class2['anomaly'] == -1, 'cpu']

a3 = df_class3.loc[df_class3['anomaly'] == 1, 'cpu']
b3 = df_class3.loc[df_class3['anomaly'] == -1, 'cpu']

plt.rcParams['figure.figsize'] = [15, 8]
fig, axs = plt.subplots(2,2)
axs[0,0].hist([a0,b0], bins=32, stacked=True, color=['blue', 'red'], label=['normal', 'anomaly'])
axs[0,1].hist([a1,b1], bins=32, stacked=True, color=['blue', 'red'], label=['normal', 'anomaly'])
axs[1,0].hist([a2,b2], bins=32, stacked=True, color=['blue', 'red'], label=['normal', 'anomaly'])
axs[1,1].hist([a3,b3], bins=32, stacked=True, color=['blue', 'red'], label=['normal', 'anomaly'])
axs[0,0].set_title("WeekEndNight")
axs[0,1].set_title("WeekEndLight")
axs[1,0].set_title("WeekDayNight")
axs[1,1].set_title("WeekDayLight")
plt.legend()
plt.show()

# %%
df_class = pd.concat([df_class0, df_class1, df_class2, df_class3])
df['anomaly22'] = df_class['anomaly']
df['anomaly22'] = np.array(df['anomaly22'] == -1).astype(float)

# %%
fig, ax = plt.subplots()

a = df.loc[df['anomaly22'] == 1, ('time_epoch', 'cpu')] #anomaly

ax.plot(df['time_epoch'], df['cpu'], color='blue')
ax.scatter(a['time_epoch'], a['cpu'], color='red')
plt.show()

# %%
a = df.loc[df['anomaly22'] == 0, 'cpu']
b = df.loc[df['anomaly22'] == 1, 'cpu']

fig, axs = plt.subplots()
axs.hist([a, b], bins=32, stacked=True, color=['blue', 'red'], label=['normal', 'anomaly'])
plt.legend()
plt.show()

# %% [markdown]
# ## Markov chains

# %%
x1 = (df['cpu'] <= 18).astype(int)
x2 = ((df['cpu'] > 18) & (df['cpu'] <= 21)).astype(int)
x3 = ((df['cpu'] > 21) & (df['cpu'] <= 24)).astype(int)
x4 = ((df['cpu'] > 24) & (df['cpu'] <= 27)).astype(int)
x5 = (df['cpu'] > 27).astype(int)
df_mm = x1 + 2*x2 + 3*x3 + 4*x4 + 5*x5
print(df_mm)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2073    1
# 2074    1
# 2075    1
# 2076    1
# 2077    1
# Name: cpu, Length: 2078, dtype: int64

# %% [markdown]
# ## Isolation Forest

# %%
data = df[['cpu', 'hours', 'daylight', 'DayOfTheWeek', 'WeekDay']]
min_max_scaler = preprocessing.StandardScaler()
np_scaled = min_max_scaler.fit_transform(data)
data = pd.DataFrame(np_scaled)
# train isolation forest 
model =  IsolationForest(contamination = outliers_fraction)
model.fit(data)
# add the data to the main  
df['anomaly25'] = pd.Series(model.predict(data))
df['anomaly25'] = df['anomaly25'].map( {1: 0, -1: 1} )
print(df['anomaly25'].value_counts())
# Out:
# 0    2057
# 1      21
# Name: anomaly25, dtype: int64

# %%
# visualisation of anomaly throughout time (viz 1)
fig, ax = plt.subplots()

a = df.loc[df['anomaly25'] == 1, ['time_epoch', 'cpu']] #anomaly

ax.plot(df['time_epoch'], df['cpu'], color='blue')
ax.scatter(a['time_epoch'],a['cpu'], color='red')
plt.show()

# %%
# visualisation of anomaly with temperature repartition (viz 2)
a = df.loc[df['anomaly25'] == 0, 'cpu']
b = df.loc[df['anomaly25'] == 1, 'cpu']

fig, axs = plt.subplots()
axs.hist([a,b], bins=32, stacked=True, color=['blue', 'red'], label = ['normal', 'anomaly'])
plt.legend()
plt.show()

# %% [markdown]
# ## One class SVM

# %%
# Take useful feature and standardize them 
data = df[['cpu', 'hours', 'daylight', 'DayOfTheWeek', 'WeekDay']]
min_max_scaler = preprocessing.StandardScaler()
np_scaled = min_max_scaler.fit_transform(data)
# train one class SVM 
model =  OneClassSVM(nu=0.95 * outliers_fraction) #nu=0.95 * outliers_fraction  + 0.05
data = pd.DataFrame(np_scaled)
model.fit(data)
# add the data to the main  
df['anomaly26'] = pd.Series(model.predict(data))
df['anomaly26'] = df['anomaly26'].map( {1: 0, -1: 1} )
print(df['anomaly26'].value_counts())
# Out:
# 0    2058
# 1      20
# Name: anomaly26, dtype: int64

# %%
# visualisation of anomaly throughout time (viz 1)
fig, ax = plt.subplots()

a = df.loc[df['anomaly26'] == 1, ['time_epoch', 'cpu']] #anomaly

ax.plot(df['time_epoch'], df['cpu'], color='blue')
ax.scatter(a['time_epoch'],a['cpu'], color='red')
plt.show()

# %%
a = df.loc[df['anomaly26'] == 0, 'cpu']
b = df.loc[df['anomaly26'] == 1, 'cpu']

fig, axs = plt.subplots()
axs.hist([a,b], bins=32, stacked=True, color=['blue', 'red'], label=['normal', 'anomaly'])
plt.legend()
plt.show()

# %% [markdown]
# # RNN

# %%
#select and standardize data
data_n = df[['cpu', 'hours', 'daylight', 'DayOfTheWeek', 'WeekDay']]
min_max_scaler = preprocessing.StandardScaler()
np_scaled = min_max_scaler.fit_transform(data_n)
data_n = pd.DataFrame(np_scaled)

# important parameters and train/test size
prediction_time = 1 
testdatasize = 295
unroll_length = 50
testdatacut = testdatasize + unroll_length  + 1

#total_row = data_n.index.stop
#prediction_time = 1 
#testdatasize = int(total_row - (total_row * 0.95))
#unroll_length = int(total_row * 0.05)
#testdatacut = testdatasize + unroll_length + 1

x_train = data_n[0:-prediction_time-testdatacut].iloc[:, 1:].values
y_train = data_n[prediction_time:-testdatacut][0].values

# test data
x_test = data_n[0-testdatacut:-prediction_time].iloc[:, 1:].values
y_test = data_n[prediction_time-testdatacut:  ][0].values

# %%
def unroll(data,sequence_length=24):
    result = []
    for index in range(len(data) - sequence_length):
        result.append(data[index: index + sequence_length])
    return np.asarray(result)

# adapt the datasets for the sequence data shape
x_train = unroll(x_train,unroll_length)
x_test  = unroll(x_test,unroll_length)
y_train = y_train[-x_train.shape[0]:]
y_test  = y_test[-x_test.shape[0]:]

# see the shape
print("x_train", x_train.shape)
print("y_train", y_train.shape)
print("x_test", x_test.shape)
print("y_test", y_test.shape)
# Out:
# x_train (1681, 50, 4)
# y_train (1681,)
# x_test (295, 50, 4)
# y_test (295,)

# %%
# specific libraries for RNN
# keras is a high layer build on Tensorflow layer to stay in high level/easy implementation
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential
import time #helper libraries
from keras.models import model_from_json
import sys

# %%
### CJB : 파라미터 다시 확인 후 조절할 것

# Build the model
model = Sequential()
model.add(LSTM(100, input_shape = (50, 4), return_sequences = True)) 
model.add(Dropout(0.2))
model.add(LSTM(100, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.add(Activation('linear'))

start = time.time()
model.compile(loss='mean_squared_error', optimizer='rmsprop')
model.summary()
print('compilation time : {}'.format(time.time() - start))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 50, 100)           42000
# _________________________________________________________________
# dropout (Dropout)            (None, 50, 100)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# _________________________________________________________________
# activation (Activation)      (None, 1)                 0
# =================================================================
# Total params: 122,501
# Trainable params: 122,501
# Non-trainable params: 0
# _________________________________________________________________
# compilation time : 0.013630390167236328

# %%
model.fit(x_train, y_train, batch_size=100, epochs=500, validation_split=0.1)
# Out:
# Epoch 1/500
# 16/16 [==============================] - 3s 161ms/step - loss: 0.1287 - val_loss: 1.5164
# Epoch 2/500
# 16/16 [==============================] - 2s 103ms/step - loss: 0.0821 - val_loss: 1.6214
# Epoch 3/500
# 16/16 [==============================] - 2s 101ms/step - loss: 0.0794 - val_loss: 1.6689
# Epoch 4/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0808 - val_loss: 1.5298
# Epoch 5/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0784 - val_loss: 1.5002
# Epoch 6/500
# 16/16 [==============================] - 2s 109ms/step - loss: 0.0739 - val_loss: 1.6306
# Epoch 7/500
# 16/16 [==============================] - 2s 109ms/step - loss: 0.0753 - val_loss: 1.3320
# Epoch 8/500
# 16/16 [==============================] - 2s 103ms/step - loss: 0.0749 - val_loss: 1.3765
# Epoch 9/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0732 - val_loss: 1.5371
# Epoch 10/500
# 16/16 [==============================] - 2s 108ms/step - loss: 0.0718 - val_loss: 1.4372
# Epoch 11/500
# 16/16 [==============================] - 2s 110ms/step - loss: 0.0738 - val_loss: 1.4098
# Epoch 12/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0730 - val_loss: 1.5247
# Epoch 13/500
# 16/16 [==============================] - 2s 106ms/step - loss: 0.0705 - val_loss: 1.4589
# Epoch 14/500
# 16/16 [==============================] - 2s 108ms/step - loss: 0.0707 - val_loss: 1.5165
# Epoch 15/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0713 - val_loss: 1.5276
# Epoch 16/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0717 - val_loss: 1.5733
# Epoch 17/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0699 - val_loss: 1.4306
# Epoch 18/500
# 16/16 [==============================] - 2s 108ms/step - loss: 0.0714 - val_loss: 1.4042
# Epoch 19/500
# 16/16 [==============================] - 2s 104ms/step - loss: 0.0712 - val_loss: 1.4607
# Epoch 20/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0697 - val_loss: 1.4247
# Epoch 21/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0704 - val_loss: 1.4519
# Epoch 22/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0700 - val_loss: 1.4938
# Epoch 23/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0697 - val_loss: 1.5376
# Epoch 24/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0691 - val_loss: 1.3550
# Epoch 25/500
# 16/16 [==============================] - 2s 123ms/step - loss: 0.0692 - val_loss: 1.4490
# Epoch 26/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0691 - val_loss: 1.4189
# Epoch 27/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0677 - val_loss: 1.4949
# Epoch 28/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0677 - val_loss: 1.4544
# Epoch 29/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0685 - val_loss: 1.5421
# Epoch 30/500
# 16/16 [==============================] - 2s 126ms/step - loss: 0.0682 - val_loss: 1.4233
# Epoch 31/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0677 - val_loss: 1.4746
# Epoch 32/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0653 - val_loss: 1.3846
# Epoch 33/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0664 - val_loss: 1.4492
# Epoch 34/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0673 - val_loss: 1.4825
# Epoch 35/500
# 16/16 [==============================] - 2s 128ms/step - loss: 0.0652 - val_loss: 1.3746
# Epoch 36/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0668 - val_loss: 1.4487
# Epoch 37/500
# 16/16 [==============================] - 2s 124ms/step - loss: 0.0651 - val_loss: 1.4848
# Epoch 38/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0651 - val_loss: 1.3853
# Epoch 39/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0653 - val_loss: 1.4565
# Epoch 40/500
# 16/16 [==============================] - 2s 126ms/step - loss: 0.0647 - val_loss: 1.4643
# Epoch 41/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0665 - val_loss: 1.5361
# Epoch 42/500
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0647 - val_loss: 1.4579
# Epoch 43/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0648 - val_loss: 1.4022
# Epoch 44/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0637 - val_loss: 1.5036
# Epoch 45/500
# 16/16 [==============================] - 2s 128ms/step - loss: 0.0638 - val_loss: 1.3669
# Epoch 46/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0646 - val_loss: 1.4832
# Epoch 47/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0636 - val_loss: 1.5091
# Epoch 48/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0630 - val_loss: 1.6607
# Epoch 49/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0639 - val_loss: 1.6074
# Epoch 50/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0642 - val_loss: 1.5300
# Epoch 51/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0629 - val_loss: 1.4771
# Epoch 52/500
# 16/16 [==============================] - 2s 123ms/step - loss: 0.0638 - val_loss: 1.4732
# Epoch 53/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0631 - val_loss: 1.4562
# Epoch 54/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0619 - val_loss: 1.4491
# Epoch 55/500
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0634 - val_loss: 1.4142
# Epoch 56/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0629 - val_loss: 1.5392
# Epoch 57/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0631 - val_loss: 1.5097
# Epoch 58/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0613 - val_loss: 1.5297
# Epoch 59/500
# 16/16 [==============================] - 2s 111ms/step - loss: 0.0613 - val_loss: 1.5889
# Epoch 60/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0628 - val_loss: 1.5110
# Epoch 61/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0633 - val_loss: 1.6690
# Epoch 62/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0620 - val_loss: 1.4538
# Epoch 63/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0619 - val_loss: 1.5238
# Epoch 64/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0619 - val_loss: 1.4360
# Epoch 65/500
# 16/16 [==============================] - 2s 126ms/step - loss: 0.0617 - val_loss: 1.5441
# Epoch 66/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0618 - val_loss: 1.5057
# Epoch 67/500
# 16/16 [==============================] - 2s 126ms/step - loss: 0.0605 - val_loss: 1.3980
# Epoch 68/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0612 - val_loss: 1.4898
# Epoch 69/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0606 - val_loss: 1.5874
# Epoch 70/500
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0618 - val_loss: 1.5215
# Epoch 71/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0617 - val_loss: 1.4911
# Epoch 72/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0616 - val_loss: 1.6049
# Epoch 73/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0604 - val_loss: 1.5753
# Epoch 74/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0613 - val_loss: 1.6655
# Epoch 75/500
# 16/16 [==============================] - 2s 125ms/step - loss: 0.0617 - val_loss: 1.5213
# Epoch 76/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0616 - val_loss: 1.5596
# Epoch 77/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0603 - val_loss: 1.4911
# Epoch 78/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0613 - val_loss: 1.4096
# Epoch 79/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0608 - val_loss: 1.4764
# Epoch 80/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0609 - val_loss: 1.4613
# Epoch 81/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0608 - val_loss: 1.5075
# Epoch 82/500
# 16/16 [==============================] - 2s 125ms/step - loss: 0.0591 - val_loss: 1.5971
# Epoch 83/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0606 - val_loss: 1.5416
# Epoch 84/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0613 - val_loss: 1.4892
# Epoch 85/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0608 - val_loss: 1.5777
# Epoch 86/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0613 - val_loss: 1.5599
# Epoch 87/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0596 - val_loss: 1.5582
# Epoch 88/500
# 16/16 [==============================] - 2s 111ms/step - loss: 0.0609 - val_loss: 1.5951
# Epoch 89/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0594 - val_loss: 1.5793
# Epoch 90/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0599 - val_loss: 1.4544
# Epoch 91/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0603 - val_loss: 1.6686
# Epoch 92/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0603 - val_loss: 1.5153
# Epoch 93/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0591 - val_loss: 1.4893
# Epoch 94/500
# 16/16 [==============================] - 2s 125ms/step - loss: 0.0596 - val_loss: 1.4689
# Epoch 95/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0596 - val_loss: 1.5786
# Epoch 96/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0609 - val_loss: 1.4999
# Epoch 97/500
# 16/16 [==============================] - 2s 126ms/step - loss: 0.0600 - val_loss: 1.5105
# Epoch 98/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0604 - val_loss: 1.5067
# Epoch 99/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0593 - val_loss: 1.4757
# Epoch 100/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0599 - val_loss: 1.4821
# Epoch 101/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0593 - val_loss: 1.4785
# Epoch 102/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0593 - val_loss: 1.4976
# Epoch 103/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0593 - val_loss: 1.4975
# Epoch 104/500
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0597 - val_loss: 1.6798
# Epoch 105/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0592 - val_loss: 1.4966
# Epoch 106/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0592 - val_loss: 1.6116
# Epoch 107/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0582 - val_loss: 1.4646
# Epoch 108/500
# 16/16 [==============================] - 2s 111ms/step - loss: 0.0588 - val_loss: 1.5261
# Epoch 109/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0588 - val_loss: 1.5068
# Epoch 110/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0592 - val_loss: 1.4494
# Epoch 111/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0586 - val_loss: 1.5752
# Epoch 112/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0584 - val_loss: 1.6634
# Epoch 113/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0588 - val_loss: 1.4185
# Epoch 114/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0573 - val_loss: 1.6571
# Epoch 115/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0589 - val_loss: 1.5049
# Epoch 116/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0580 - val_loss: 1.5317
# Epoch 117/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0584 - val_loss: 1.5807
# Epoch 118/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0580 - val_loss: 1.4970
# Epoch 119/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0592 - val_loss: 1.5435
# Epoch 120/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0592 - val_loss: 1.6400
# Epoch 121/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0582 - val_loss: 1.5318
# Epoch 122/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0591 - val_loss: 1.4673
# Epoch 123/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0584 - val_loss: 1.5137
# Epoch 124/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0583 - val_loss: 1.4625
# Epoch 125/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0577 - val_loss: 1.5543
# Epoch 126/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0571 - val_loss: 1.5807
# Epoch 127/500
# 16/16 [==============================] - 2s 123ms/step - loss: 0.0582 - val_loss: 1.4791
# Epoch 128/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0577 - val_loss: 1.4531
# Epoch 129/500
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0567 - val_loss: 1.4732
# Epoch 130/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0571 - val_loss: 1.4969
# Epoch 131/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0580 - val_loss: 1.5384
# Epoch 132/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0565 - val_loss: 1.4864
# Epoch 133/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0573 - val_loss: 1.5065
# Epoch 134/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0569 - val_loss: 1.5336
# Epoch 135/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0572 - val_loss: 1.5254
# Epoch 136/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0576 - val_loss: 1.4298
# Epoch 137/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0573 - val_loss: 1.5197
# Epoch 138/500
# 16/16 [==============================] - 2s 111ms/step - loss: 0.0573 - val_loss: 1.4820
# Epoch 139/500
# 16/16 [==============================] - 2s 123ms/step - loss: 0.0565 - val_loss: 1.5970
# Epoch 140/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0572 - val_loss: 1.4937
# Epoch 141/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0557 - val_loss: 1.6270
# Epoch 142/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0579 - val_loss: 1.5859
# Epoch 143/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0552 - val_loss: 1.5476
# Epoch 144/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0554 - val_loss: 1.5542
# Epoch 145/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0565 - val_loss: 1.4727
# Epoch 146/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0568 - val_loss: 1.5913
# Epoch 147/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0555 - val_loss: 1.5085
# Epoch 148/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0567 - val_loss: 1.4709
# Epoch 149/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0555 - val_loss: 1.4517
# Epoch 150/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0566 - val_loss: 1.4936
# Epoch 151/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0559 - val_loss: 1.4465
# Epoch 152/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0562 - val_loss: 1.5410
# Epoch 153/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0561 - val_loss: 1.4707
# Epoch 154/500
# 16/16 [==============================] - 2s 124ms/step - loss: 0.0561 - val_loss: 1.4827
# Epoch 155/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0568 - val_loss: 1.5983
# Epoch 156/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0564 - val_loss: 1.5495
# Epoch 157/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0552 - val_loss: 1.6446
# Epoch 158/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0554 - val_loss: 1.5706
# Epoch 159/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0554 - val_loss: 1.6162
# Epoch 160/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0556 - val_loss: 1.5525
# Epoch 161/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0555 - val_loss: 1.5120
# Epoch 162/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0550 - val_loss: 1.5382
# Epoch 163/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0557 - val_loss: 1.5422
# Epoch 164/500
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0548 - val_loss: 1.5452
# Epoch 165/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0562 - val_loss: 1.4958
# Epoch 166/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0549 - val_loss: 1.4748
# Epoch 167/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0549 - val_loss: 1.5855
# Epoch 168/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0551 - val_loss: 1.4546
# Epoch 169/500
# 16/16 [==============================] - 2s 125ms/step - loss: 0.0549 - val_loss: 1.4905
# Epoch 170/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0544 - val_loss: 1.4600
# Epoch 171/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0556 - val_loss: 1.5760
# Epoch 172/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0551 - val_loss: 1.5366
# Epoch 173/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0541 - val_loss: 1.5615
# Epoch 174/500
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0552 - val_loss: 1.4965
# Epoch 175/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0543 - val_loss: 1.4971
# Epoch 176/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0545 - val_loss: 1.5234
# Epoch 177/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0551 - val_loss: 1.4958
# Epoch 178/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0534 - val_loss: 1.6000
# Epoch 179/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0549 - val_loss: 1.5542
# Epoch 180/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0544 - val_loss: 1.5901
# Epoch 181/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0543 - val_loss: 1.5756
# Epoch 182/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0539 - val_loss: 1.5807
# Epoch 183/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0563 - val_loss: 1.5566
# Epoch 184/500
# 16/16 [==============================] - 2s 125ms/step - loss: 0.0540 - val_loss: 1.5104
# Epoch 185/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0541 - val_loss: 1.4699
# Epoch 186/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0544 - val_loss: 1.5198
# Epoch 187/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0544 - val_loss: 1.5601
# Epoch 188/500
# 16/16 [==============================] - 2s 124ms/step - loss: 0.0543 - val_loss: 1.5221
# Epoch 189/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0533 - val_loss: 1.5529
# Epoch 190/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0546 - val_loss: 1.5211
# Epoch 191/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0548 - val_loss: 1.5295
# Epoch 192/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0544 - val_loss: 1.4851
# Epoch 193/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0540 - val_loss: 1.5520
# Epoch 194/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0548 - val_loss: 1.4910
# Epoch 195/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0533 - val_loss: 1.5303
# Epoch 196/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0534 - val_loss: 1.5259
# Epoch 197/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0539 - val_loss: 1.4492
# Epoch 198/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0529 - val_loss: 1.5997
# Epoch 199/500
# 16/16 [==============================] - 2s 123ms/step - loss: 0.0539 - val_loss: 1.4922
# Epoch 200/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0528 - val_loss: 1.4650
# Epoch 201/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0531 - val_loss: 1.4984
# Epoch 202/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0539 - val_loss: 1.5103
# Epoch 203/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0534 - val_loss: 1.5074
# Epoch 204/500
# 16/16 [==============================] - 2s 126ms/step - loss: 0.0535 - val_loss: 1.5150
# Epoch 205/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0529 - val_loss: 1.4461
# Epoch 206/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0542 - val_loss: 1.4673
# Epoch 207/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0537 - val_loss: 1.4068
# Epoch 208/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0537 - val_loss: 1.4554
# Epoch 209/500
# 16/16 [==============================] - 2s 125ms/step - loss: 0.0541 - val_loss: 1.5339
# Epoch 210/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0524 - val_loss: 1.5474
# Epoch 211/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0537 - val_loss: 1.4931
# Epoch 212/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0532 - val_loss: 1.5210
# Epoch 213/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0532 - val_loss: 1.4928
# Epoch 214/500
# 16/16 [==============================] - 2s 128ms/step - loss: 0.0530 - val_loss: 1.4683
# Epoch 215/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0538 - val_loss: 1.4919
# Epoch 216/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0529 - val_loss: 1.4980
# Epoch 217/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0529 - val_loss: 1.5448
# Epoch 218/500
# 16/16 [==============================] - 2s 125ms/step - loss: 0.0528 - val_loss: 1.5727
# Epoch 219/500
# 16/16 [==============================] - 2s 123ms/step - loss: 0.0526 - val_loss: 1.4913
# Epoch 220/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0539 - val_loss: 1.5507
# Epoch 221/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0522 - val_loss: 1.5710
# Epoch 222/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0522 - val_loss: 1.5387
# Epoch 223/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0528 - val_loss: 1.6345
# Epoch 224/500
# 16/16 [==============================] - 2s 125ms/step - loss: 0.0526 - val_loss: 1.4928
# Epoch 225/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0528 - val_loss: 1.4726
# Epoch 226/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0535 - val_loss: 1.4904
# Epoch 227/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0532 - val_loss: 1.4810
# Epoch 228/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0530 - val_loss: 1.5039
# Epoch 229/500
# 16/16 [==============================] - 2s 124ms/step - loss: 0.0529 - val_loss: 1.4583
# Epoch 230/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0533 - val_loss: 1.5416
# Epoch 231/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0525 - val_loss: 1.4531
# Epoch 232/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0524 - val_loss: 1.4613
# Epoch 233/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0529 - val_loss: 1.4983
# Epoch 234/500
# 16/16 [==============================] - 2s 131ms/step - loss: 0.0523 - val_loss: 1.5910
# Epoch 235/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0525 - val_loss: 1.6021
# Epoch 236/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0520 - val_loss: 1.4396
# Epoch 237/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0521 - val_loss: 1.5642
# Epoch 238/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0524 - val_loss: 1.5612
# Epoch 239/500
# 16/16 [==============================] - 2s 123ms/step - loss: 0.0512 - val_loss: 1.6023
# Epoch 240/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0529 - val_loss: 1.5088
# Epoch 241/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0525 - val_loss: 1.5718
# Epoch 242/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0522 - val_loss: 1.5188
# Epoch 243/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0519 - val_loss: 1.4989
# Epoch 244/500
# 16/16 [==============================] - 2s 124ms/step - loss: 0.0521 - val_loss: 1.5459
# Epoch 245/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0525 - val_loss: 1.5748
# Epoch 246/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0514 - val_loss: 1.5323
# Epoch 247/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0523 - val_loss: 1.3774
# Epoch 248/500
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0529 - val_loss: 1.5528
# Epoch 249/500
# 16/16 [==============================] - 2s 123ms/step - loss: 0.0526 - val_loss: 1.4869
# Epoch 250/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0524 - val_loss: 1.4137
# Epoch 251/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0517 - val_loss: 1.5646
# Epoch 252/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0508 - val_loss: 1.4958
# Epoch 253/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0525 - val_loss: 1.5355
# Epoch 254/500
# 16/16 [==============================] - 2s 124ms/step - loss: 0.0517 - val_loss: 1.5910
# Epoch 255/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0515 - val_loss: 1.5247
# Epoch 256/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0517 - val_loss: 1.5442
# Epoch 257/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0520 - val_loss: 1.5127
# Epoch 258/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0513 - val_loss: 1.5604
# Epoch 259/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0519 - val_loss: 1.5645
# Epoch 260/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0508 - val_loss: 1.4580
# Epoch 261/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0517 - val_loss: 1.4611
# Epoch 262/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0510 - val_loss: 1.4926
# Epoch 263/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0509 - val_loss: 1.5986
# Epoch 264/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0514 - val_loss: 1.4823
# Epoch 265/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0521 - val_loss: 1.4738
# Epoch 266/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0521 - val_loss: 1.4362
# Epoch 267/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0510 - val_loss: 1.5828
# Epoch 268/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0509 - val_loss: 1.5172
# Epoch 269/500
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0509 - val_loss: 1.5356
# Epoch 270/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0515 - val_loss: 1.5451
# Epoch 271/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0514 - val_loss: 1.5028
# Epoch 272/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0519 - val_loss: 1.5328
# Epoch 273/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0514 - val_loss: 1.5470
# Epoch 274/500
# 16/16 [==============================] - 2s 124ms/step - loss: 0.0516 - val_loss: 1.5289
# Epoch 275/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0513 - val_loss: 1.4748
# Epoch 276/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0514 - val_loss: 1.5053
# Epoch 277/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0506 - val_loss: 1.5337
# Epoch 278/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0516 - val_loss: 1.4945
# Epoch 279/500
# 16/16 [==============================] - 2s 127ms/step - loss: 0.0501 - val_loss: 1.5467
# Epoch 280/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0515 - val_loss: 1.5808
# Epoch 281/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0500 - val_loss: 1.5793
# Epoch 282/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0505 - val_loss: 1.4984
# Epoch 283/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0510 - val_loss: 1.5159
# Epoch 284/500
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0502 - val_loss: 1.4859
# Epoch 285/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0503 - val_loss: 1.6250
# Epoch 286/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0512 - val_loss: 1.4779
# Epoch 287/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0510 - val_loss: 1.5514
# Epoch 288/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0502 - val_loss: 1.4863
# Epoch 289/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0513 - val_loss: 1.6070
# Epoch 290/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0505 - val_loss: 1.5936
# Epoch 291/500
# 16/16 [==============================] - 2s 123ms/step - loss: 0.0508 - val_loss: 1.5484
# Epoch 292/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0513 - val_loss: 1.5791
# Epoch 293/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0506 - val_loss: 1.5564
# Epoch 294/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0509 - val_loss: 1.5632
# Epoch 295/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0504 - val_loss: 1.4777
# Epoch 296/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0507 - val_loss: 1.5467
# Epoch 297/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0507 - val_loss: 1.5471
# Epoch 298/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0504 - val_loss: 1.5887
# Epoch 299/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0499 - val_loss: 1.4896
# Epoch 300/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0504 - val_loss: 1.5510
# Epoch 301/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0500 - val_loss: 1.5527
# Epoch 302/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0494 - val_loss: 1.4922
# Epoch 303/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0510 - val_loss: 1.4345
# Epoch 304/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0499 - val_loss: 1.4077
# Epoch 305/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0498 - val_loss: 1.4933
# Epoch 306/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0504 - val_loss: 1.5829
# Epoch 307/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0502 - val_loss: 1.5011
# Epoch 308/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0493 - val_loss: 1.5552
# Epoch 309/500
# 16/16 [==============================] - 2s 123ms/step - loss: 0.0501 - val_loss: 1.4973
# Epoch 310/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0497 - val_loss: 1.4477
# Epoch 311/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0501 - val_loss: 1.5472
# Epoch 312/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0494 - val_loss: 1.4874
# Epoch 313/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0502 - val_loss: 1.4630
# Epoch 314/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0497 - val_loss: 1.5088
# Epoch 315/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0503 - val_loss: 1.5610
# Epoch 316/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0507 - val_loss: 1.5126
# Epoch 317/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0490 - val_loss: 1.4867
# Epoch 318/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0499 - val_loss: 1.5283
# Epoch 319/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0494 - val_loss: 1.5462
# Epoch 320/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0501 - val_loss: 1.5136
# Epoch 321/500
# 16/16 [==============================] - 2s 123ms/step - loss: 0.0491 - val_loss: 1.6669
# Epoch 322/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0499 - val_loss: 1.5180
# Epoch 323/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0487 - val_loss: 1.5656
# Epoch 324/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0494 - val_loss: 1.4298
# Epoch 325/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0491 - val_loss: 1.5029
# Epoch 326/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0503 - val_loss: 1.4670
# Epoch 327/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0500 - val_loss: 1.5021
# Epoch 328/500
# 16/16 [==============================] - 2s 123ms/step - loss: 0.0495 - val_loss: 1.5336
# Epoch 329/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0498 - val_loss: 1.4972
# Epoch 330/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0498 - val_loss: 1.4826
# Epoch 331/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0487 - val_loss: 1.5312
# Epoch 332/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0491 - val_loss: 1.4735
# Epoch 333/500
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0497 - val_loss: 1.5411
# Epoch 334/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0489 - val_loss: 1.4955
# Epoch 335/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0484 - val_loss: 1.4840
# Epoch 336/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0504 - val_loss: 1.4747
# Epoch 337/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0483 - val_loss: 1.5541
# Epoch 338/500
# 16/16 [==============================] - 2s 124ms/step - loss: 0.0492 - val_loss: 1.5819
# Epoch 339/500
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0486 - val_loss: 1.5878
# Epoch 340/500
# 16/16 [==============================] - 2s 125ms/step - loss: 0.0489 - val_loss: 1.5410
# Epoch 341/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0486 - val_loss: 1.6200
# Epoch 342/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0502 - val_loss: 1.5227
# Epoch 343/500
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0481 - val_loss: 1.6079
# Epoch 344/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0486 - val_loss: 1.4973
# Epoch 345/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0495 - val_loss: 1.5591
# Epoch 346/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0481 - val_loss: 1.5721
# Epoch 347/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0493 - val_loss: 1.5384
# Epoch 348/500
# 16/16 [==============================] - 2s 127ms/step - loss: 0.0486 - val_loss: 1.5466
# Epoch 349/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0492 - val_loss: 1.4873
# Epoch 350/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0489 - val_loss: 1.5312
# Epoch 351/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0493 - val_loss: 1.4667
# Epoch 352/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0494 - val_loss: 1.4677
# Epoch 353/500
# 16/16 [==============================] - 2s 123ms/step - loss: 0.0492 - val_loss: 1.4972
# Epoch 354/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0489 - val_loss: 1.5304
# Epoch 355/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0488 - val_loss: 1.5191
# Epoch 356/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0490 - val_loss: 1.4822
# Epoch 357/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0479 - val_loss: 1.5291
# Epoch 358/500
# 16/16 [==============================] - 2s 124ms/step - loss: 0.0483 - val_loss: 1.5388
# Epoch 359/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0490 - val_loss: 1.5472
# Epoch 360/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0484 - val_loss: 1.4831
# Epoch 361/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0483 - val_loss: 1.5983
# Epoch 362/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0484 - val_loss: 1.5555
# Epoch 363/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0482 - val_loss: 1.5806
# Epoch 364/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0497 - val_loss: 1.5548
# Epoch 365/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0488 - val_loss: 1.4676
# Epoch 366/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0483 - val_loss: 1.5512
# Epoch 367/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0490 - val_loss: 1.4998
# Epoch 368/500
# 16/16 [==============================] - 2s 125ms/step - loss: 0.0489 - val_loss: 1.5666
# Epoch 369/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0478 - val_loss: 1.5013
# Epoch 370/500
# 16/16 [==============================] - 2s 126ms/step - loss: 0.0482 - val_loss: 1.5633
# Epoch 371/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0494 - val_loss: 1.5340
# Epoch 372/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0475 - val_loss: 1.6024
# Epoch 373/500
# 16/16 [==============================] - 2s 127ms/step - loss: 0.0483 - val_loss: 1.5973
# Epoch 374/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0484 - val_loss: 1.5470
# Epoch 375/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0492 - val_loss: 1.5554
# Epoch 376/500
# 16/16 [==============================] - 2s 111ms/step - loss: 0.0480 - val_loss: 1.5563
# Epoch 377/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0477 - val_loss: 1.5120
# Epoch 378/500
# 16/16 [==============================] - 2s 127ms/step - loss: 0.0476 - val_loss: 1.5164
# Epoch 379/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0478 - val_loss: 1.5236
# Epoch 380/500
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0480 - val_loss: 1.5213
# Epoch 381/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0479 - val_loss: 1.5686
# Epoch 382/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0471 - val_loss: 1.5848
# Epoch 383/500
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0474 - val_loss: 1.5955
# Epoch 384/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0491 - val_loss: 1.5643
# Epoch 385/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0482 - val_loss: 1.4891
# Epoch 386/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0471 - val_loss: 1.5350
# Epoch 387/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0481 - val_loss: 1.5026
# Epoch 388/500
# 16/16 [==============================] - 2s 131ms/step - loss: 0.0483 - val_loss: 1.5472
# Epoch 389/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0478 - val_loss: 1.5485
# Epoch 390/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0477 - val_loss: 1.5260
# Epoch 391/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0479 - val_loss: 1.4814
# Epoch 392/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0485 - val_loss: 1.4460
# Epoch 393/500
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0478 - val_loss: 1.6112
# Epoch 394/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0483 - val_loss: 1.5484
# Epoch 395/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0476 - val_loss: 1.5140
# Epoch 396/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0475 - val_loss: 1.5075
# Epoch 397/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0476 - val_loss: 1.6302
# Epoch 398/500
# 16/16 [==============================] - 2s 131ms/step - loss: 0.0473 - val_loss: 1.5484
# Epoch 399/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0476 - val_loss: 1.5535
# Epoch 400/500
# 16/16 [==============================] - 2s 124ms/step - loss: 0.0466 - val_loss: 1.5064
# Epoch 401/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0478 - val_loss: 1.5399
# Epoch 402/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0467 - val_loss: 1.5505
# Epoch 403/500
# 16/16 [==============================] - 2s 125ms/step - loss: 0.0481 - val_loss: 1.5275
# Epoch 404/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0472 - val_loss: 1.5451
# Epoch 405/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0476 - val_loss: 1.5331
# Epoch 406/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0467 - val_loss: 1.5283
# Epoch 407/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0465 - val_loss: 1.5575
# Epoch 408/500
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0469 - val_loss: 1.6091
# Epoch 409/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0474 - val_loss: 1.5652
# Epoch 410/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0479 - val_loss: 1.5211
# Epoch 411/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0475 - val_loss: 1.4633
# Epoch 412/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0476 - val_loss: 1.4813
# Epoch 413/500
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0465 - val_loss: 1.5959
# Epoch 414/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0472 - val_loss: 1.5296
# Epoch 415/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0473 - val_loss: 1.5677
# Epoch 416/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0472 - val_loss: 1.5598
# Epoch 417/500
# 16/16 [==============================] - 2s 124ms/step - loss: 0.0466 - val_loss: 1.5360
# Epoch 418/500
# 16/16 [==============================] - 2s 129ms/step - loss: 0.0470 - val_loss: 1.6141
# Epoch 419/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0468 - val_loss: 1.5102
# Epoch 420/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0475 - val_loss: 1.5847
# Epoch 421/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0471 - val_loss: 1.6031
# Epoch 422/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0473 - val_loss: 1.5942
# Epoch 423/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0466 - val_loss: 1.5215
# Epoch 424/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0467 - val_loss: 1.5258
# Epoch 425/500
# 16/16 [==============================] - 2s 125ms/step - loss: 0.0469 - val_loss: 1.5423
# Epoch 426/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0466 - val_loss: 1.5255
# Epoch 427/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0464 - val_loss: 1.5670
# Epoch 428/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0475 - val_loss: 1.5804
# Epoch 429/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0464 - val_loss: 1.5295
# Epoch 430/500
# 16/16 [==============================] - 2s 126ms/step - loss: 0.0464 - val_loss: 1.5696
# Epoch 431/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0467 - val_loss: 1.5310
# Epoch 432/500
# 16/16 [==============================] - 2s 123ms/step - loss: 0.0455 - val_loss: 1.5773
# Epoch 433/500
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0459 - val_loss: 1.5555
# Epoch 434/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0476 - val_loss: 1.4206
# Epoch 435/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0465 - val_loss: 1.5821
# Epoch 436/500
# 16/16 [==============================] - 2s 111ms/step - loss: 0.0469 - val_loss: 1.5689
# Epoch 437/500
# 16/16 [==============================] - 2s 125ms/step - loss: 0.0458 - val_loss: 1.5264
# Epoch 438/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0462 - val_loss: 1.5086
# Epoch 439/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0467 - val_loss: 1.4863
# Epoch 440/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0468 - val_loss: 1.5741
# Epoch 441/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0472 - val_loss: 1.5300
# Epoch 442/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0457 - val_loss: 1.5718
# Epoch 443/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0456 - val_loss: 1.6481
# Epoch 444/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0462 - val_loss: 1.5171
# Epoch 445/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0460 - val_loss: 1.5308
# Epoch 446/500
# 16/16 [==============================] - 2s 111ms/step - loss: 0.0463 - val_loss: 1.5077
# Epoch 447/500
# 16/16 [==============================] - 2s 124ms/step - loss: 0.0472 - val_loss: 1.5747
# Epoch 448/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0468 - val_loss: 1.4600
# Epoch 449/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0465 - val_loss: 1.5411
# Epoch 450/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0453 - val_loss: 1.5269
# Epoch 451/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0454 - val_loss: 1.5050
# Epoch 452/500
# 16/16 [==============================] - 2s 124ms/step - loss: 0.0457 - val_loss: 1.4715
# Epoch 453/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0450 - val_loss: 1.5668
# Epoch 454/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0458 - val_loss: 1.5038
# Epoch 455/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0454 - val_loss: 1.5025
# Epoch 456/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0473 - val_loss: 1.5612
# Epoch 457/500
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0458 - val_loss: 1.5234
# Epoch 458/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0470 - val_loss: 1.5691
# Epoch 459/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0457 - val_loss: 1.5514
# Epoch 460/500
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0463 - val_loss: 1.5698
# Epoch 461/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0452 - val_loss: 1.5183
# Epoch 462/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0460 - val_loss: 1.5165
# Epoch 463/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0448 - val_loss: 1.5136
# Epoch 464/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0460 - val_loss: 1.5327
# Epoch 465/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0454 - val_loss: 1.6063
# Epoch 466/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0449 - val_loss: 1.5134
# Epoch 467/500
# 16/16 [==============================] - 2s 124ms/step - loss: 0.0459 - val_loss: 1.4837
# Epoch 468/500
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0472 - val_loss: 1.5213
# Epoch 469/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0451 - val_loss: 1.5493
# Epoch 470/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0459 - val_loss: 1.5433
# Epoch 471/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0449 - val_loss: 1.5633
# Epoch 472/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0445 - val_loss: 1.5610
# Epoch 473/500
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0448 - val_loss: 1.5483
# Epoch 474/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0449 - val_loss: 1.6004
# Epoch 475/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0454 - val_loss: 1.5806
# Epoch 476/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0453 - val_loss: 1.5661
# Epoch 477/500
# 16/16 [==============================] - 2s 125ms/step - loss: 0.0456 - val_loss: 1.5185
# Epoch 478/500
# 16/16 [==============================] - 2s 123ms/step - loss: 0.0454 - val_loss: 1.5127
# Epoch 479/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0444 - val_loss: 1.5964
# Epoch 480/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0458 - val_loss: 1.5438
# Epoch 481/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0446 - val_loss: 1.5702
# Epoch 482/500
# 16/16 [==============================] - 2s 125ms/step - loss: 0.0460 - val_loss: 1.5745
# Epoch 483/500
# 16/16 [==============================] - 2s 124ms/step - loss: 0.0449 - val_loss: 1.5252
# Epoch 484/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0449 - val_loss: 1.5561
# Epoch 485/500
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0442 - val_loss: 1.6059
# Epoch 486/500
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0445 - val_loss: 1.5223
# Epoch 487/500
# 16/16 [==============================] - 2s 123ms/step - loss: 0.0455 - val_loss: 1.6238
# Epoch 488/500
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0453 - val_loss: 1.5769
# Epoch 489/500
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0443 - val_loss: 1.5439
# Epoch 490/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0446 - val_loss: 1.5504
# Epoch 491/500
# 16/16 [==============================] - 2s 125ms/step - loss: 0.0449 - val_loss: 1.5139
# Epoch 492/500
# 16/16 [==============================] - 2s 124ms/step - loss: 0.0446 - val_loss: 1.5752
# Epoch 493/500
# 16/16 [==============================] - 2s 123ms/step - loss: 0.0443 - val_loss: 1.4776
# Epoch 494/500
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0449 - val_loss: 1.5553
# Epoch 495/500
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0445 - val_loss: 1.5691
# Epoch 496/500
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0445 - val_loss: 1.5815
# Epoch 497/500
# 16/16 [==============================] - 2s 126ms/step - loss: 0.0452 - val_loss: 1.5302
# Epoch 498/500
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0444 - val_loss: 1.5764
# Epoch 499/500
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0455 - val_loss: 1.5590
# Epoch 500/500
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0450 - val_loss: 1.6193

# %%
loaded_model = model
diff=[]
ratio=[]
p = loaded_model.predict(x_test)
# predictions = lstm.predict_sequences_multiple(loaded_model, x_test, 50, 50)
for u in range(len(y_test)):
    pr = p[u][0]
    ratio.append((y_test[u]/pr)-1)
    diff.append(abs(y_test[u]- pr))

# %%
fig, axs = plt.subplots()
axs.plot(p,color='red', label='prediction')
axs.plot(y_test,color='blue', label='y_test')
plt.legend(loc='upper left')
plt.show()
